# %%
import os
import os.path as osp
from pathlib import Path
import json
import pickle
import collections as C
import itertools as I

from common.constants import CORE_OPTIONS
from common.utils import remove_comments, remove_spaces, chunk_list
from common.pantograph.dataclasses import ProblemGenerationProcess

header = ("""
import Mathlib
import Aesop

""" + '\n'.join('set_option ' + t.replace('=', ' ') for t in CORE_OPTIONS)).strip()
print(header)
# Out:
# import Mathlib
# import Aesop
#
# set_option maxHeartbeats 0
# set_option maxRecDepth 100000
# set_option tactic.hygienic false
# set_option pp.fullNames true
# set_option pp.funBinderTypes true
# set_option pp.piBinderTypes true

# %%
# result_pkl_path = '/home/ma-user/workspace/formal_problem_generation/formal_problem_generation/output/sft_ar_v2/Goedel-Prover-V2-8B.Numina-Lean.problem_generator/problem_generation.20250822-005458.pkl'
# result_pkl_path = '/home/ma-user/workspace/formal_problem_generation/formal_problem_generation/output/sft_ar_v2/Goedel-Prover-V2-8B.Numina-Lean.problem_generator.nopack/problem_generation.20250828-223616.pkl'
# result_pkl_path = '/home/ma-user/workspace/formal_problem_generation/formal_problem_generation/output/sft_ar_v2/Goedel-Prover-V2-8B.Numina-Lean-reasseblmed.39509.problem_generator.nopack/problem_generation.20250903-221358.pkl'
# result_pkl_path = '/home/ma-user/workspace/formal_problem_generation/formal_problem_generation/output/sft_wg/Goedel-Prover-V2-8B.Numina-Lean.whole_statement_generatior.nopack/problem_generation.20250828-210118.pkl'
result_pkl_path = '/home/ma-user/workspace/formal_problem_generation/formal_problem_generation/output/sft_ar_v3/Goedel-Prover-V2-8B.Numina-Lean-reasseblmed.39509+FineLeanCorpus-reasseblmed.82438.problem_generator.nopack/problem_generation.20250906-021846.pkl'

# %%
path_chunks = result_pkl_path.strip('/').split('/')
agent = path_chunks[-3]
model_name = path_chunks[-2]
print(agent, model_name)
# Out:
# sft_ar_v3 Goedel-Prover-V2-8B.Numina-Lean-reasseblmed.39509+FineLeanCorpus-reasseblmed.82438.problem_generator.nopack

# %%
# with open(result_pkl_path, 'rb') as f:
#     data = pickle.load(f)

# results_all = C.defaultdict(list)
# idx_cnt = C.Counter()
# for ((ptype, source), idx), v in data.items():
#     idx_cnt[idx] += 1
#     results_all[(ptype, source)].append(v)

with open(result_pkl_path, 'rb') as f:
    conditions_sampled, finished = pickle.load(f)

# %%
# KC_cnt = C.Counter()
# for v in results_all.values():
#     for vv in v:
#         if (vv.formal_solution_draft or '') != '':
#             KC_cnt[len(remove_spaces(remove_comments(vv.formal_solution_draft)))] += 1
# print(sum((k * v) for (k, v) in KC_cnt.items()) / sum(KC_cnt.values()))

KC_cnt = C.Counter()
for vv in finished:
    if (vv.formal_solution_draft or '') != '':
        KC_cnt[len(remove_spaces(remove_comments(vv.formal_solution_draft)))] += 1
print(sum((k * v) for (k, v) in KC_cnt.items()) / sum(KC_cnt.values()))
# Out:
# 274.141670991178

# %%
print('''
Agent\t{}
Model\t{}
#Proven\t{}
#Typechecked\t{}
#All\t{}
#Prompt Tokens\t{}
#Completion Tokens\t{}
Avg. KC@1\t{}
'''.format(
agent,
model_name,
sum([len([vv for vv in finished if (vv.formal_solution_draft or '') != ''])]),
sum([len([vv for vv in finished if (vv.formal_statement or '') != ''])]),
sum([len(finished)]),
sum([json.loads(vv.metainfo).get('prompt_tokens', 0) for vv in finished]),
sum([json.loads(vv.metainfo).get('completion_tokens', 0) for vv in finished]),
sum((k * v) for (k, v) in KC_cnt.items()) / sum(KC_cnt.values())
))
# Out:
# Agent	sft_ar_v3
# Model	Goedel-Prover-V2-8B.Numina-Lean-reasseblmed.39509+FineLeanCorpus-reasseblmed.82438.problem_generator.nopack
# #Proven	3854
# #Typechecked	3854
# #All	5000
# #Prompt Tokens	62130198
# #Completion Tokens	14437556
# Avg. KC@1	274.141670991178

# %%
def format_condition(conditions: dict) -> str:
    if 'problem_type' in conditions.keys():
        assert 'source' in conditions.keys()
        # Numina-Lean
        # problem_type: str, e.g. unknown
        # source: str, e.g. unknown
        return f'Source=NuminaLean, problem_type={conditions["problem_type"]}, source={conditions["source"]}'
    elif 'domain' in conditions.keys():
        assert 'difficulty' in conditions.keys()
        # FineLeanCorups
        # domain: List[str], e.g. ['Algebra -> Intermediate Algebra -> Other', 'Applied Mathematics -> Other -> Other']
        # difficulty: int, e.g. 1
        return f'Source=FineLeanCorups, domain={conditions["domain"]}, difficulty={conditions["difficulty"]}'

# %%
subject_cnt = C.Counter()
difficulty_cnt = C.Counter()

# %%
# for (ptype, source), ds in results_all.items():
assert len(conditions_sampled) == len(finished)
output_lean_root = osp.join('/home/ma-user/workspace/formal_problem_generation/formal_problem_generation/data/MiniF2F/results', model_name)
os.makedirs(output_lean_root, exist_ok=True)

results_all = sorted(list(zip(conditions_sampled, finished)), key=lambda x : x[0])
for i_chunk, chunk in chunk_list(results_all, chunksize=20):
    with open(osp.join(output_lean_root, f'{i_chunk}.lean'), 'w') as f:
        f.write(header + '\n\n')
        for (c, d) in chunk:
            c = {k : v for (k, v) in c}
            if 'problem_type' in c:
                subject_cnt[c['problem_type']] += 1
            if 'difficulty' in c:
                difficulty_cnt[c['difficulty']] += 1
            # raise
            if d.formal_solution_draft is not None:
                f.write('-- ' + format_condition(c)+'\n')
                assert d.formal_statement.endswith(':= sorry')
                f.write('\n'.join(l + ' in' for l in d.header.splitlines()) + '\n' + d.formal_statement[:-len(' sorry')] + ' by\n' + d.formal_solution_draft + '\n\n')

# %%
subject_cnt
# Out:
# Counter({'Algebra': 755,
#          'Number Theory': 387,
#          'unknown': 227,
#          'Inequalities': 200,
#          'Calculus': 32,
#          'Other': 12,
#          'NaN': 9,
#          'Combinatorics': 5,
#          'Geometry': 3,
#          'Intermediate Algebra': 1,
#          'Logic and Puzzles': 1})

# %%
c
# Out:
# {'problem_type': 'Algebra', 'source': 'olympiads'}

# %%
len(C.Counter(conditions_sampled))
# Out:
# 1023

# %%
C.Counter(conditions_sampled)
# Out:
# Counter({(('difficulty', '1'),
#           ('domain', "['Algebra -> Intermediate Algebra -> Other']")): 420,
#          (('problem_type', 'Algebra'), ('source', 'olympiads')): 407,
#          (('problem_type', 'unknown'), ('source', 'unknown')): 227,
#          (('problem_type', 'Number Theory'), ('source', 'olympiads')): 195,
#          (('difficulty', '5'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities']")): 194,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials']")): 111,
#          (('problem_type', 'Inequalities'), ('source', 'olympiads')): 97,
#          (('problem_type', 'Algebra'), ('source', 'secondary_math')): 92,
#          (('difficulty', '2'),
#           ('domain', "['Algebra -> Intermediate Algebra -> Other']")): 70,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities']")): 64,
#          (('problem_type', 'Algebra'), ('source', 'math_train')): 60,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities']")): 48,
#          (('problem_type', 'Algebra'), ('source', 'math_test')): 47,
#          (('problem_type', 'Algebra'), ('source', 'amc_aime')): 44,
#          (('difficulty', '1'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility']")): 42,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials']")): 42,
#          (('problem_type', 'Number Theory'), ('source', 'aops_forum')): 40,
#          (('difficulty', '6'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities']")): 40,
#          (('difficulty', '3'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities']")): 39,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations']")): 39,
#          (('problem_type', 'Algebra'), ('source', 'olympiads_ref')): 38,
#          (('problem_type', 'Inequalities'), ('source', 'inequalities')): 35,
#          (('problem_type', 'Inequalities'), ('source', 'aops_forum')): 34,
#          (('difficulty', '7'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations']")): 33,
#          (('difficulty', '4'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities']")): 32,
#          (('problem_type', 'Number Theory'), ('source', 'olympiads_ref')): 31,
#          (('difficulty', '1'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Coordinate Geometry']")): 28,
#          (('difficulty', '1'),
#           ('domain',
#            "['Combinatorics -> Enumerative Combinatorics -> Combinations']")): 27,
#          (('problem_type', 'Number Theory'), ('source', 'number_theory')): 27,
#          (('difficulty', '4'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations']")): 27,
#          (('problem_type', 'Algebra'), ('source', 'cn_k12')): 27,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations']")): 25,
#          (('difficulty', '2'),
#           ('domain', "['Calculus -> Integral Calculus -> Other']")): 25,
#          (('difficulty', '1'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Other']")): 24,
#          (('difficulty', '1'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Modular Arithmetic']")): 24,
#          (('problem_type', 'Number Theory'), ('source', 'synthetic')): 23,
#          (('difficulty', '7'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities']")): 23,
#          (('difficulty', '1'),
#           ('domain',
#            "['Combinatorics -> Enumerative Combinatorics -> Other']")): 23,
#          (('difficulty', '1'),
#           ('domain', "['Geometry -> Euclidean Geometry -> Other']")): 22,
#          (('difficulty', '2'),
#           ('domain',
#            "['Calculus -> Integral Calculus -> Definite Integrals']")): 21,
#          (('problem_type', 'Algebra'), ('source', 'aops_forum')): 21,
#          (('difficulty', '2'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility']")): 19,
#          (('problem_type', 'Inequalities'), ('source', 'secondary_math')): 19,
#          (('difficulty', '2'),
#           ('domain',
#            "['Calculus -> Differential Calculus -> Derivatives']")): 19,
#          (('problem_type', 'Number Theory'), ('source', 'math_train')): 18,
#          (('difficulty', '4'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations']")): 18,
#          (('problem_type', 'Number Theory'), ('source', 'secondary_math')): 18,
#          (('difficulty', '1'),
#           ('domain', "['Applied Mathematics -> Probability -> Other']")): 18,
#          (('problem_type', 'Calculus'), ('source', 'olympiads')): 18,
#          (('difficulty', '4'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials']")): 17,
#          (('difficulty', '4'),
#           ('domain',
#            "['Calculus -> Integral Calculus -> Definite Integrals']")): 17,
#          (('problem_type', 'Number Theory'), ('source', 'amc_aime')): 16,
#          (('difficulty', '4'),
#           ('domain', "['Algebra -> Intermediate Algebra -> Other']")): 16,
#          (('difficulty', '1'),
#           ('domain', "['Geometry -> Euclidean Geometry -> Triangles']")): 15,
#          (('difficulty', '2'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Modular Arithmetic']")): 15,
#          (('difficulty', '5'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Algebra -> Intermediate Algebra -> Polynomials']")): 15,
#          (('difficulty', '1'),
#           ('domain', "['Algebra -> Linear Algebra -> Vector Spaces']")): 14,
#          (('difficulty', '3'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials']")): 14,
#          (('difficulty', '5'),
#           ('domain', "['Algebra -> Intermediate Algebra -> Other']")): 14,
#          (('difficulty', '3'),
#           ('domain', "['Algebra -> Intermediate Algebra -> Other']")): 14,
#          (('difficulty', '5'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations']")): 13,
#          (('difficulty', '2'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations']")): 13,
#          (('difficulty', '4'),
#           ('domain', "['Calculus -> Integral Calculus -> Other']")): 13,
#          (('difficulty', '5'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials']")): 13,
#          (('problem_type', 'Inequalities'), ('source', 'olympiads_ref')): 12,
#          (('difficulty', '1'),
#           ('domain',
#            "['Combinatorics -> Enumerative Combinatorics -> Permutations']")): 12,
#          (('difficulty', '6'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations']")): 12,
#          (('difficulty', '4'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility']")): 12,
#          (('difficulty', '5'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations']")): 12,
#          (('difficulty', '2'),
#           ('domain',
#            "['Combinatorics -> Enumerative Combinatorics -> Other']")): 12,
#          (('difficulty', '2'),
#           ('domain', "['Calculus -> Other -> Other']")): 11,
#          (('problem_type', 'Number Theory'), ('source', 'math_test')): 11,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Algebra -> Intermediate Algebra -> Other']")): 11,
#          (('difficulty', '1'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations']")): 10,
#          (('difficulty', '2'),
#           ('domain',
#            "['Combinatorics -> Enumerative Combinatorics -> Combinations']")): 10,
#          (('difficulty', '3'),
#           ('domain',
#            "['Calculus -> Integral Calculus -> Definite Integrals']")): 10,
#          (('problem_type', 'Algebra'), ('source', 'cn_contest')): 10,
#          (('difficulty', '1'),
#           ('domain',
#            "['Calculus -> Differential Calculus -> Derivatives']")): 10,
#          (('difficulty', '6'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations']")): 9,
#          (('difficulty', '5'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Geometry -> Euclidean Geometry -> Triangles']")): 9,
#          (('difficulty', '2'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Other']")): 9,
#          (('difficulty', '4'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Algebra -> Intermediate Algebra -> Other']")): 9,
#          (('difficulty', '2'),
#           ('domain', "['Geometry -> Euclidean Geometry -> Triangles']")): 9,
#          (('difficulty', '2'),
#           ('domain', "['Calculus -> Differential Calculus -> Other']")): 8,
#          (('difficulty', '3'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations']")): 8,
#          (('difficulty', '3'),
#           ('domain', "['Calculus -> Integral Calculus -> Other']")): 8,
#          (('difficulty', '6'),
#           ('domain',
#            "['Calculus -> Integral Calculus -> Definite Integrals']")): 8,
#          (('difficulty', '1'),
#           ('domain', "['Geometry -> Euclidean Geometry -> Circles']")): 8,
#          (('difficulty', '1'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Prime Numbers']")): 7,
#          (('difficulty', '4'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Other']")): 7,
#          (('difficulty', '3'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations']")): 7,
#          (('difficulty', '2'),
#           ('domain', "['Algebra -> Linear Algebra -> Matrices']")): 7,
#          (('problem_type', 'Algebra'), ('source', 'inequalities')): 7,
#          (('problem_type', 'NaN'), ('source', 'olympiads')): 7,
#          (('difficulty', '1'),
#           ('domain',
#            "['Discrete Mathematics -> Set Theory -> Cardinality']")): 7,
#          (('difficulty', '1'),
#           ('domain', "['Calculus -> Integral Calculus -> Other']")): 7,
#          (('difficulty', '2'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Coordinate Geometry']")): 7,
#          (('difficulty', '1'),
#           ('domain',
#            "['Applied Mathematics -> Probability -> Expected Value']")): 6,
#          (('difficulty', '8'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities']")): 6,
#          (('difficulty', '2'),
#           ('domain',
#            "['Calculus -> Differential Calculus -> Applications of Derivatives']")): 6,
#          (('difficulty', '6'),
#           ('domain', "['Algebra -> Intermediate Algebra -> Other']")): 6,
#          (('difficulty', '1'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Other', 'Algebra -> Intermediate Algebra -> Other']")): 6,
#          (('difficulty', '3'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility']")): 6,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Algebra -> Intermediate Algebra -> Other']")): 6,
#          (('problem_type', 'Other'), ('source', 'olympiads_ref')): 6,
#          (('difficulty', '4'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations', 'Number Theory -> Elementary Number Theory -> Other']")): 6,
#          (('difficulty', '6'),
#           ('domain', "['Algebra -> Intermediate Algebra -> Polynomials']")): 6,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Algebra -> Intermediate Algebra -> Polynomials']")): 6,
#          (('difficulty', '4'),
#           ('domain', "['Calculus -> Other -> Other']")): 6,
#          (('difficulty', '7'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations']")): 6,
#          (('problem_type', 'Number Theory'), ('source', 'cn_contest')): 6,
#          (('difficulty', '6'),
#           ('domain', "['Calculus -> Integral Calculus -> Other']")): 6,
#          (('difficulty', '8'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations']")): 5,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Algebra -> Intermediate Algebra -> Other']")): 5,
#          (('difficulty', '3'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Modular Arithmetic']")): 5,
#          (('difficulty', '5'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility']")): 5,
#          (('difficulty', '3'),
#           ('domain', "['Geometry -> Euclidean Geometry -> Triangles']")): 5,
#          (('problem_type', 'Combinatorics'), ('source', 'olympiads_ref')): 5,
#          (('difficulty', '2'),
#           ('domain', "['Geometry -> Euclidean Geometry -> Other']")): 5,
#          (('difficulty', '1'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility', 'Combinatorics -> Enumerative Combinatorics -> Other']")): 5,
#          (('difficulty', '6'),
#           ('domain', "['Algebra -> Linear Algebra -> Matrices']")): 5,
#          (('difficulty', '1'),
#           ('domain',
#            "['Calculus -> Integral Calculus -> Definite Integrals']")): 5,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Algebra -> Intermediate Algebra -> Other']")): 5,
#          (('difficulty', '3'),
#           ('domain',
#            "['Combinatorics -> Enumerative Combinatorics -> Other']")): 5,
#          (('difficulty', '7'),
#           ('domain', "['Calculus -> Integral Calculus -> Other']")): 5,
#          (('difficulty', '1'),
#           ('domain', "['Algebra -> Linear Algebra -> Matrices']")): 5,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Geometry -> Euclidean Geometry -> Other']")): 5,
#          (('difficulty', '2'),
#           ('domain',
#            "['Combinatorics -> Enumerative Combinatorics -> Permutations']")): 5,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Calculus -> Differential Calculus -> Applications of Derivatives']")): 5,
#          (('difficulty', '6'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility']")): 5,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Number Theory -> Elementary Number Theory -> Other']")): 5,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Algebra -> Intermediate Algebra -> Other']")): 5,
#          (('difficulty', '3'),
#           ('domain', "['Algebra -> Linear Algebra -> Matrices']")): 5,
#          (('difficulty', '4'),
#           ('domain',
#            "['Calculus -> Differential Calculus -> Derivatives']")): 4,
#          (('difficulty', '4'),
#           ('domain',
#            "['Combinatorics -> Enumerative Combinatorics -> Combinations']")): 4,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Algebra -> Intermediate Algebra -> Other']")): 4,
#          (('difficulty', '1'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility', 'Number Theory -> Elementary Number Theory -> Modular Arithmetic']")): 4,
#          (('difficulty', '5'),
#           ('domain',
#            "['Calculus -> Integral Calculus -> Definite Integrals']")): 4,
#          (('difficulty', '3'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Geometry -> Euclidean Geometry -> Triangles']")): 4,
#          (('difficulty', '2'),
#           ('domain', "['Algebra -> Linear Algebra -> Vector Spaces']")): 4,
#          (('difficulty', '4'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Calculus -> Other -> Other']")): 4,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Calculus -> Integral Calculus -> Other']")): 4,
#          (('difficulty', '3'),
#           ('domain',
#            "['Calculus -> Differential Calculus -> Derivatives']")): 4,
#          (('difficulty', '5'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Algebra -> Intermediate Algebra -> Other']")): 4,
#          (('difficulty', '7'),
#           ('domain', "['Algebra -> Intermediate Algebra -> Other']")): 4,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Number Theory -> Elementary Number Theory -> Other']")): 4,
#          (('difficulty', '1'),
#           ('domain',
#            "['Applied Mathematics -> Probability -> Other', 'Combinatorics -> Enumerative Combinatorics -> Combinations']")): 4,
#          (('difficulty', '1'),
#           ('domain', "['Discrete Mathematics -> Set Theory -> Other']")): 4,
#          (('difficulty', '4'),
#           ('domain',
#            "['Combinatorics -> Enumerative Combinatorics -> Other']")): 4,
#          (('difficulty', '4'),
#           ('domain',
#            "['Calculus -> Differential Calculus -> Applications of Derivatives']")): 4,
#          (('difficulty', '6'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Geometry -> Euclidean Geometry -> Triangles']")): 4,
#          (('difficulty', '4'),
#           ('domain', "['Algebra -> Linear Algebra -> Matrices']")): 4,
#          (('problem_type', 'Calculus'), ('source', 'aops_forum')): 4,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Algebra -> Intermediate Algebra -> Functional Equations']")): 4,
#          (('difficulty', '2'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Prime Numbers']")): 4,
#          (('problem_type', 'Calculus'), ('source', 'math_test')): 4,
#          (('difficulty', '1'),
#           ('domain',
#            "['Calculus -> Differential Calculus -> Applications of Derivatives']")): 4,
#          (('problem_type', 'Other'), ('source', 'olympiads')): 4,
#          (('difficulty', '3'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Algebra -> Intermediate Algebra -> Other']")): 4,
#          (('difficulty', '5'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Algebra -> Intermediate Algebra -> Other']")): 4,
#          (('difficulty', '5'),
#           ('domain', "['Calculus -> Integral Calculus -> Other']")): 4,
#          (('difficulty', '4'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Modular Arithmetic']")): 4,
#          (('difficulty', '1'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Coordinate Geometry', 'Algebra -> Intermediate Algebra -> Other']")): 4,
#          (('difficulty', '7'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility']")): 4,
#          (('difficulty', '2'),
#           ('domain',
#            "['Calculus -> Differential Calculus -> Derivatives', 'Algebra -> Intermediate Algebra -> Other']")): 4,
#          (('difficulty', '4'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility', 'Number Theory -> Elementary Number Theory -> Other']")): 4,
#          (('difficulty', '7'),
#           ('domain',
#            "['Calculus -> Integral Calculus -> Definite Integrals']")): 4,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Algebra -> Intermediate Algebra -> Inequalities']")): 4,
#          (('difficulty', '5'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Calculus -> Differential Calculus -> Applications of Derivatives']")): 4,
#          (('difficulty', '7'),
#           ('domain', "['Algebra -> Intermediate Algebra -> Polynomials']")): 4,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Calculus -> Differential Calculus -> Derivatives']")): 4,
#          (('difficulty', '5'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Algebra -> Intermediate Algebra -> Other']")): 4,
#          (('difficulty', '1'),
#           ('domain', "['Discrete Mathematics -> Other -> Other']")): 4,
#          (('difficulty', '4'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Calculus -> Integral Calculus -> Other']")): 3,
#          (('difficulty', '1'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations', 'Algebra -> Intermediate Algebra -> Other']")): 3,
#          (('difficulty', '3'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Algebra -> Intermediate Algebra -> Polynomials']")): 3,
#          (('difficulty', '1'),
#           ('domain', "['Calculus -> Differential Calculus -> Other']")): 3,
#          (('difficulty', '2'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility', 'Number Theory -> Elementary Number Theory -> Other']")): 3,
#          (('difficulty', '2'),
#           ('domain', "['Applied Mathematics -> Probability -> Other']")): 3,
#          (('difficulty', '3'),
#           ('domain',
#            "['Combinatorics -> Enumerative Combinatorics -> Combinations']")): 3,
#          (('difficulty', '7'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Algebra -> Intermediate Algebra -> Inequalities']")): 3,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Calculus -> Differential Calculus -> Applications of Derivatives']")): 3,
#          (('difficulty', '4'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations', 'Algebra -> Intermediate Algebra -> Other']")): 3,
#          (('difficulty', '7'),
#           ('domain', "['Algebra -> Linear Algebra -> Matrices']")): 3,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Algebra -> Intermediate Algebra -> Inequalities']")): 3,
#          (('difficulty', '7'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Modular Arithmetic']")): 3,
#          (('difficulty', '5'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Modular Arithmetic']")): 3,
#          (('difficulty', '2'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations', 'Number Theory -> Elementary Number Theory -> Other']")): 3,
#          (('difficulty', '2'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility', 'Number Theory -> Elementary Number Theory -> Modular Arithmetic']")): 3,
#          (('difficulty', '6'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Other']")): 3,
#          (('difficulty', '5'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Algebra -> Intermediate Algebra -> Functional Equations']")): 3,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Applied Mathematics -> Optimization -> Other']")): 3,
#          (('difficulty', '3'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Other']")): 3,
#          (('difficulty', '4'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Algebra -> Intermediate Algebra -> Other']")): 3,
#          (('difficulty', '4'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Calculus -> Differential Calculus -> Applications of Derivatives']")): 3,
#          (('difficulty', '1'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Other', 'Combinatorics -> Enumerative Combinatorics -> Other']")): 3,
#          (('difficulty', '1'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility', 'Number Theory -> Elementary Number Theory -> Other']")): 3,
#          (('difficulty', '5'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations', 'Algebra -> Intermediate Algebra -> Other']")): 3,
#          (('difficulty', '0'),
#           ('domain', "['Algebra -> Intermediate Algebra -> Other']")): 3,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Algebra -> Intermediate Algebra -> Polynomials']")): 3,
#          (('difficulty', '4'),
#           ('domain',
#            "['Calculus -> Integral Calculus -> Definite Integrals', 'Calculus -> Integral Calculus -> Other']")): 3,
#          (('difficulty', '4'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Algebra -> Intermediate Algebra -> Functional Equations']")): 3,
#          (('difficulty', '1'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Prime Numbers', 'Number Theory -> Elementary Number Theory -> Divisibility']")): 3,
#          (('difficulty', '3'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Coordinate Geometry']")): 3,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Algebra -> Intermediate Algebra -> Functional Equations']")): 3,
#          (('difficulty', '2'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations', 'Algebra -> Intermediate Algebra -> Other']")): 3,
#          (('difficulty', '4'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Prime Numbers', 'Number Theory -> Elementary Number Theory -> Diophantine Equations']")): 3,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Geometry -> Euclidean Geometry -> Coordinate Geometry']")): 3,
#          (('difficulty', '4'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations', 'Number Theory -> Elementary Number Theory -> Prime Numbers']")): 3,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Number Theory -> Elementary Number Theory -> Other']")): 3,
#          (('difficulty', '2'),
#           ('domain',
#            "['Applied Mathematics -> Probability -> Conditional Probability']")): 3,
#          (('difficulty', '2'),
#           ('domain',
#            "['Calculus -> Integral Calculus -> Other', 'Algebra -> Intermediate Algebra -> Other']")): 3,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Geometry -> Euclidean Geometry -> Triangles']")): 3,
#          (('problem_type', 'Calculus'), ('source', 'math_train')): 3,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Geometry -> Euclidean Geometry -> Other']")): 3,
#          (('difficulty', '6'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Prime Numbers', 'Number Theory -> Elementary Number Theory -> Divisibility']")): 3,
#          (('difficulty', '6'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Calculus -> Differential Calculus -> Applications of Derivatives']")): 3,
#          (('difficulty', '5'),
#           ('domain', "['Algebra -> Linear Algebra -> Matrices']")): 3,
#          (('difficulty', '4'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations', 'Algebra -> Intermediate Algebra -> Polynomials']")): 3,
#          (('difficulty', '3'),
#           ('domain',
#            "['Calculus -> Differential Calculus -> Applications of Derivatives']")): 3,
#          (('difficulty', '2'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Triangles', 'Algebra -> Intermediate Algebra -> Other']")): 3,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Algebra -> Intermediate Algebra -> Inequalities']")): 3,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Number Theory -> Elementary Number Theory -> Diophantine Equations']")): 3,
#          (('difficulty', '4'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Algebra -> Intermediate Algebra -> Functional Equations']")): 3,
#          (('difficulty', '4'),
#           ('domain',
#            "['Calculus -> Integral Calculus -> Other', 'Algebra -> Intermediate Algebra -> Other']")): 3,
#          (('difficulty', '6'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Triangles', 'Algebra -> Intermediate Algebra -> Inequalities']")): 3,
#          (('difficulty', '3'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Calculus -> Differential Calculus -> Applications of Derivatives']")): 3,
#          (('difficulty', '4'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Number Theory -> Elementary Number Theory -> Other']")): 3,
#          (('difficulty', '6'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Modular Arithmetic']")): 3,
#          (('difficulty', '1'),
#           ('domain',
#            "['Applied Mathematics -> Probability -> Conditional Probability']")): 3,
#          (('difficulty', '4'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Algebra -> Intermediate Algebra -> Inequalities']")): 3,
#          (('difficulty', '4'),
#           ('domain',
#            "['Calculus -> Integral Calculus -> Definite Integrals', 'Algebra -> Intermediate Algebra -> Inequalities']")): 2,
#          (('difficulty', '4'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility', 'Number Theory -> Elementary Number Theory -> Modular Arithmetic']")): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Calculus -> Integral Calculus -> Other']")): 2,
#          (('difficulty', '3'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Triangles', 'Algebra -> Intermediate Algebra -> Other']")): 2,
#          (('difficulty', '6'),
#           ('domain', "['Discrete Mathematics -> Other -> Other']")): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Triangles', 'Algebra -> Intermediate Algebra -> Inequalities']")): 2,
#          (('difficulty', '3'),
#           ('domain', "['Calculus -> Differential Calculus -> Other']")): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Calculus -> Differential Calculus -> Applications of Derivatives']")): 2,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Calculus -> Differential Calculus -> Applications of Derivatives']")): 2,
#          (('difficulty', '5'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations', 'Algebra -> Intermediate Algebra -> Polynomials']")): 2,
#          (('difficulty', '3'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Algebra -> Intermediate Algebra -> Functional Equations']")): 2,
#          (('difficulty', '4'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Prime Numbers', 'Number Theory -> Elementary Number Theory -> Other']")): 2,
#          (('difficulty', '6'),
#           ('domain',
#            "['Calculus -> Differential Calculus -> Derivatives']")): 2,
#          (('difficulty', '6'),
#           ('domain',
#            "['Calculus -> Differential Calculus -> Applications of Derivatives']")): 2,
#          (('difficulty', '8'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations']")): 2,
#          (('difficulty', '4'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Number Theory -> Elementary Number Theory -> Other']")): 2,
#          (('difficulty', '5'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations', 'Number Theory -> Elementary Number Theory -> Divisibility']")): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Algebra -> Intermediate Algebra -> Functional Equations']")): 2,
#          (('difficulty', '5'),
#           ('domain', "['Geometry -> Euclidean Geometry -> Triangles']")): 2,
#          (('difficulty', '3'),
#           ('domain',
#            "['Combinatorics -> Enumerative Combinatorics -> Permutations']")): 2,
#          (('difficulty', '6'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Algebra -> Intermediate Algebra -> Functional Equations']")): 2,
#          (('difficulty', '4'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility', 'Number Theory -> Elementary Number Theory -> Prime Numbers']")): 2,
#          (('difficulty', '1'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Triangles', 'Algebra -> Intermediate Algebra -> Inequalities']")): 2,
#          (('difficulty', '7'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Triangles', 'Algebra -> Intermediate Algebra -> Inequalities']")): 2,
#          (('difficulty', '3'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Algebra -> Intermediate Algebra -> Other']")): 2,
#          (('difficulty', '1'),
#           ('domain', "['Applied Mathematics -> Other -> Other']")): 2,
#          (('difficulty', '7'),
#           ('domain',
#            "['Calculus -> Integral Calculus -> Other', 'Algebra -> Intermediate Algebra -> Other']")): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Calculus -> Differential Calculus -> Derivatives']")): 2,
#          (('difficulty', '5'),
#           ('domain',
#            "['Combinatorics -> Enumerative Combinatorics -> Other']")): 2,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Calculus -> Integral Calculus -> Other']")): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Applied Mathematics -> Probability -> Expected Value']")): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Other', 'Algebra -> Intermediate Algebra -> Other']")): 2,
#          (('difficulty', '3'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Algebra -> Intermediate Algebra -> Inequalities']")): 2,
#          (('difficulty', '0'),
#           ('domain',
#            "['Combinatorics -> Enumerative Combinatorics -> Other']")): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility', 'Combinatorics -> Enumerative Combinatorics -> Other']")): 2,
#          (('difficulty', '4'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Algebra -> Intermediate Algebra -> Polynomials']")): 2,
#          (('difficulty', '5'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Triangles', 'Algebra -> Intermediate Algebra -> Inequalities']")): 2,
#          (('difficulty', '4'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Algebra -> Intermediate Algebra -> Other']")): 2,
#          (('difficulty', '8'),
#           ('domain',
#            "['Calculus -> Integral Calculus -> Definite Integrals']")): 2,
#          (('difficulty', '5'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations', 'Number Theory -> Elementary Number Theory -> Prime Numbers']")): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Other', 'Combinatorics -> Enumerative Combinatorics -> Other']")): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Calculus -> Integral Calculus -> Definite Integrals', 'Algebra -> Intermediate Algebra -> Inequalities']")): 2,
#          (('difficulty', '1'),
#           ('domain', "['Calculus -> Other -> Other']")): 2,
#          (('difficulty', '4'),
#           ('domain',
#            "['Combinatorics -> Enumerative Combinatorics -> Combinations', 'Algebra -> Intermediate Algebra -> Other']")): 2,
#          (('difficulty', '1'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Other', 'Algebra -> Intermediate Algebra -> Other']")): 2,
#          (('difficulty', '5'),
#           ('domain',
#            "['Calculus -> Differential Calculus -> Applications of Derivatives']")): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Calculus -> Differential Calculus -> Derivatives']")): 2,
#          (('difficulty', '4'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Algebra -> Intermediate Algebra -> Inequalities']")): 2,
#          (('difficulty', '5'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Algebra -> Intermediate Algebra -> Polynomials']")): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Calculus -> Differential Calculus -> Derivatives']")): 2,
#          (('difficulty', '1'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility', 'Number Theory -> Elementary Number Theory -> Prime Numbers']")): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Calculus -> Differential Calculus -> Derivatives', 'Calculus -> Integral Calculus -> Other']")): 2,
#          (('difficulty', '5'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Other']")): 2,
#          (('difficulty', '6'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility', 'Number Theory -> Elementary Number Theory -> Other']")): 2,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Algebra -> Intermediate Algebra -> Polynomials']")): 2,
#          (('difficulty', '3'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Algebra -> Intermediate Algebra -> Inequalities']")): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Other', 'Algebra -> Intermediate Algebra -> Other']")): 2,
#          (('problem_type', 'Other'), ('source', 'aops_forum')): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Algebra -> Intermediate Algebra -> Polynomials']")): 2,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Linear Algebra -> Vector Spaces', 'Geometry -> Euclidean Geometry -> Coordinate Geometry']")): 2,
#          (('difficulty', '7'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Algebra -> Intermediate Algebra -> Functional Equations']")): 2,
#          (('difficulty', '7'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Algebra -> Intermediate Algebra -> Polynomials']")): 2,
#          (('difficulty', '7'),
#           ('domain',
#            "['Calculus -> Differential Calculus -> Applications of Derivatives']")): 2,
#          (('difficulty', '6'),
#           ('domain', "['Geometry -> Euclidean Geometry -> Triangles']")): 2,
#          (('difficulty', '3'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Algebra -> Intermediate Algebra -> Other']")): 2,
#          (('difficulty', '4'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Prime Numbers', 'Number Theory -> Elementary Number Theory -> Divisibility']")): 2,
#          (('difficulty', '4'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Coordinate Geometry']")): 2,
#          (('difficulty', '6'),
#           ('domain',
#            "['Combinatorics -> Extremal Combinatorics -> Pigeonhole Principle']")): 2,
#          (('difficulty', '3'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Triangles', 'Algebra -> Intermediate Algebra -> Inequalities']")): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Coordinate Geometry', 'Algebra -> Intermediate Algebra -> Other']")): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Number Theory -> Elementary Number Theory -> Divisibility']")): 2,
#          (('difficulty', '6'),
#           ('domain',
#            "['Combinatorics -> Enumerative Combinatorics -> Other']")): 2,
#          (('difficulty', '1'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Triangles', 'Geometry -> Euclidean Geometry -> Coordinate Geometry']")): 2,
#          (('difficulty', '1'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility', 'Algebra -> Intermediate Algebra -> Other']")): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Calculus -> Other -> Other']")): 2,
#          (('difficulty', '4'),
#           ('domain', "['Calculus -> Differential Calculus -> Other']")): 2,
#          (('difficulty', '3'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility', 'Number Theory -> Elementary Number Theory -> Modular Arithmetic']")): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Prime Numbers', 'Number Theory -> Elementary Number Theory -> Divisibility']")): 2,
#          (('difficulty', '4'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Number Theory -> Elementary Number Theory -> Other']")): 2,
#          (('difficulty', '4'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Number Theory -> Elementary Number Theory -> Diophantine Equations']")): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Number Theory -> Elementary Number Theory -> Diophantine Equations']")): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Calculus -> Differential Calculus -> Other']")): 2,
#          (('difficulty', '5'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Algebra -> Intermediate Algebra -> Inequalities']")): 2,
#          (('difficulty', '6'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Algebra -> Intermediate Algebra -> Inequalities']")): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Prime Numbers', 'Number Theory -> Elementary Number Theory -> Other']")): 2,
#          (('difficulty', '2'),
#           ('domain', "['Discrete Mathematics -> Other -> Other']")): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations', 'Algebra -> Intermediate Algebra -> Polynomials']")): 2,
#          (('difficulty', '6'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Prime Numbers']")): 2,
#          (('difficulty', '3'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Calculus -> Integral Calculus -> Other']")): 2,
#          (('problem_type', 'Geometry'), ('source', 'olympiads_ref')): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility', 'Number Theory -> Elementary Number Theory -> Prime Numbers']")): 2,
#          (('difficulty', '3'),
#           ('domain', "['Geometry -> Euclidean Geometry -> Other']")): 2,
#          (('difficulty', '7'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Number Theory -> Elementary Number Theory -> Divisibility']")): 2,
#          (('difficulty', '2'),
#           ('domain', "['Calculus -> Other -> Limits']")): 2,
#          (('difficulty', '1'),
#           ('domain',
#            "['Calculus -> Differential Calculus -> Derivatives', 'Algebra -> Intermediate Algebra -> Other']")): 2,
#          (('difficulty', '6'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations', 'Number Theory -> Elementary Number Theory -> Prime Numbers']")): 2,
#          (('difficulty', '3'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Number Theory -> Elementary Number Theory -> Diophantine Equations']")): 2,
#          (('difficulty', '1'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Circles', 'Algebra -> Intermediate Algebra -> Other']")): 2,
#          (('difficulty', '6'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Algebra -> Intermediate Algebra -> Polynomials']")): 2,
#          (('difficulty', '4'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Other', 'Algebra -> Intermediate Algebra -> Other']")): 2,
#          (('difficulty', '1'),
#           ('domain',
#            "['Discrete Mathematics -> Logic -> Propositional Logic']")): 2,
#          (('difficulty', '4'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility', 'Number Theory -> Elementary Number Theory -> Diophantine Equations']")): 2,
#          (('difficulty', '5'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Number Theory -> Elementary Number Theory -> Diophantine Equations']")): 2,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Number Theory -> Elementary Number Theory -> Diophantine Equations']")): 2,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Calculus -> Differential Calculus -> Derivatives']")): 2,
#          (('difficulty', '6'),
#           ('domain',
# ...
#          (('difficulty', '3'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Prime Numbers', 'Number Theory -> Elementary Number Theory -> Other']")): 1,
#          (('difficulty', '6'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Number Theory -> Elementary Number Theory -> Divisibility']")): 1,
#          (('difficulty', '5'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Prime Numbers']")): 1,
#          (('difficulty', '7'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility', 'Algebra -> Intermediate Algebra -> Inequalities']")): 1,
#          (('difficulty', '1'),
#           ('domain',
#            "['Combinatorics -> Enumerative Combinatorics -> Other', 'Number Theory -> Elementary Number Theory -> Other']")): 1,
#          (('difficulty', '7'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Number Theory -> Elementary Number Theory -> Modular Arithmetic']")): 1,
#          (('difficulty', '6'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations', 'Number Theory -> Elementary Number Theory -> Other']")): 1,
#          (('difficulty', '2'),
#           ('domain',
#            "['Applied Mathematics -> Probability -> Other', 'Algebra -> Intermediate Algebra -> Inequalities']")): 1,
#          (('difficulty', '2'),
#           ('domain',
#            "['Discrete Mathematics -> Set Theory -> Cardinality']")): 1,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Calculus -> Differential Calculus -> Derivatives']")): 1,
#          (('difficulty', '7'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Modular Arithmetic', 'Number Theory -> Elementary Number Theory -> Diophantine Equations']")): 1,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Applied Mathematics -> Probability -> Other']")): 1,
#          (('difficulty', '3'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Algebra -> Intermediate Algebra -> Other', 'Applied Mathematics -> Optimization -> Other']")): 1,
#          (('difficulty', '6'),
#           ('domain',
#            "['Combinatorics -> Extremal Combinatorics -> Other']")): 1,
#          (('difficulty', '7'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Algebra -> Intermediate Algebra -> Functional Equations', 'Algebra -> Intermediate Algebra -> Other']")): 1,
#          (('difficulty', '4'),
#           ('domain',
#            "['Combinatorics -> Enumerative Combinatorics -> Other', 'Number Theory -> Elementary Number Theory -> Divisibility']")): 1,
#          (('difficulty', '7'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Combinatorics -> Enumerative Combinatorics -> Other']")): 1,
#          (('difficulty', '7'),
#           ('domain',
#            "['Calculus -> Differential Calculus -> Derivatives']")): 1,
#          (('difficulty', '2'),
#           ('domain',
#            "['Discrete Mathematics -> Set Theory -> Other', 'Algebra -> Intermediate Algebra -> Other']")): 1,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Geometry -> Euclidean Geometry -> Coordinate Geometry']")): 1,
#          (('difficulty', '3'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Algebra -> Intermediate Algebra -> Functional Equations']")): 1,
#          (('difficulty', '2'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Triangles', 'Geometry -> Euclidean Geometry -> Coordinate Geometry']")): 1,
#          (('difficulty', '2'),
#           ('domain',
#            "['Calculus -> Differential Calculus -> Other', 'Algebra -> Intermediate Algebra -> Inequalities']")): 1,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Geometry -> Euclidean Geometry -> Triangles']")): 1,
#          (('difficulty', '7'),
#           ('domain',
#            "['Combinatorics -> Enumerative Combinatorics -> Other', 'Algebra -> Intermediate Algebra -> Other']")): 1,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Geometry -> Euclidean Geometry -> Circles']")): 1,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Number Theory -> Elementary Number Theory -> Modular Arithmetic']")): 1,
#          (('difficulty', '1'),
#           ('domain',
#            "['Combinatorics -> Enumerative Combinatorics -> Combinations', 'Applied Mathematics -> Probability -> Other']")): 1,
#          (('difficulty', '5'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Number Theory -> Elementary Number Theory -> Divisibility']")): 1,
#          (('difficulty', '4'),
#           ('domain', "['Algebra -> Linear Algebra -> Vector Spaces']")): 1,
#          (('difficulty', '4'),
#           ('domain',
#            "['Calculus -> Integral Calculus -> Other', 'Calculus -> Differential Calculus -> Other']")): 1,
#          (('difficulty', '5'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Algebra -> Intermediate Algebra -> Inequalities']")): 1,
#          (('difficulty', '3'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Number Theory -> Elementary Number Theory -> Diophantine Equations']")): 1,
#          (('difficulty', '3'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations', 'Algebra -> Intermediate Algebra -> Functional Equations']")): 1,
#          (('difficulty', '2'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Coordinate Geometry', 'Geometry -> Analytic Geometry -> Conic Sections']")): 1,
#          (('problem_type', 'Intermediate Algebra'), ('source', 'unknown')): 1,
#          (('difficulty', '3'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Coordinate Geometry', 'Algebra -> Intermediate Algebra -> Other']")): 1,
#          (('difficulty', '1'),
#           ('domain',
#            "['Discrete Mathematics -> Set Theory -> Other', 'Algebra -> Intermediate Algebra -> Other']")): 1,
#          (('difficulty', '7'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Number Theory -> Elementary Number Theory -> Other']")): 1,
#          (('difficulty', '3'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Triangles', 'Geometry -> Euclidean Geometry -> Coordinate Geometry']")): 1,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Combinatorics -> Enumerative Combinatorics -> Other']")): 1,
#          (('difficulty', '6'),
#           ('domain',
#            "['Discrete Mathematics -> Set Theory -> Cardinality']")): 1,
#          (('difficulty', '4'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Modular Arithmetic', 'Number Theory -> Elementary Number Theory -> Diophantine Equations']")): 1,
#          (('difficulty', '1'),
#           ('domain',
#            "['Combinatorics -> Enumerative Combinatorics -> Other', 'Algebra -> Intermediate Algebra -> Other']")): 1,
#          (('difficulty', '4'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Number Theory -> Elementary Number Theory -> Prime Numbers']")): 1,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Calculus -> Differential Calculus -> Derivatives', 'Algebra -> Intermediate Algebra -> Other']")): 1,
#          (('difficulty', '6'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Number Theory -> Elementary Number Theory -> Divisibility']")): 1,
#          (('difficulty', '7'),
#           ('domain', "['Calculus -> Differential Calculus -> Other']")): 1,
#          (('problem_type', 'Inequalities'), ('source', 'amc_aime')): 1,
#          (('difficulty', '7'),
#           ('domain', "['Algebra -> Linear Algebra -> Vector Spaces']")): 1,
#          (('difficulty', '6'),
#           ('domain',
#            "['Combinatorics -> Enumerative Combinatorics -> Permutations']")): 1,
#          (('difficulty', '6'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Prime Numbers', 'Number Theory -> Elementary Number Theory -> Other']")): 1,
#          (('difficulty', '5'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Calculus -> Differential Calculus -> Derivatives', 'Algebra -> Intermediate Algebra -> Other']")): 1,
#          (('difficulty', '4'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Calculus -> Differential Calculus -> Derivatives']")): 1,
#          (('difficulty', '3'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Geometry -> Euclidean Geometry -> Coordinate Geometry']")): 1,
#          (('difficulty', '7'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations', 'Algebra -> Intermediate Algebra -> Functional Equations']")): 1,
#          (('difficulty', '2'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Coordinate Geometry', 'Geometry -> Euclidean Geometry -> Other']")): 1,
#          (('difficulty', '8'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations', 'Algebra -> Intermediate Algebra -> Inequalities']")): 1,
#          (('difficulty', '6'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Polynomials', 'Algebra -> Intermediate Algebra -> Other']")): 1,
#          (('difficulty', '7'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Inequalities', 'Geometry -> Euclidean Geometry -> Triangles']")): 1,
#          (('difficulty', '2'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Geometry -> Analytic Geometry -> Conic Sections']")): 1,
#          (('difficulty', '1'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Modular Arithmetic', 'Number Theory -> Elementary Number Theory -> Diophantine Equations']")): 1,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Discrete Mathematics -> Set Theory -> Other']")): 1,
#          (('difficulty', '7'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Calculus -> Other -> Other']")): 1,
#          (('difficulty', '6'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Prime Numbers', 'Number Theory -> Elementary Number Theory -> Diophantine Equations']")): 1,
#          (('difficulty', '4'),
#           ('domain',
#            "['Calculus -> Integral Calculus -> Other', 'Algebra -> Intermediate Algebra -> Functional Equations']")): 1,
#          (('difficulty', '2'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Modular Arithmetic', 'Combinatorics -> Enumerative Combinatorics -> Other']")): 1,
#          (('difficulty', '7'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Calculus -> Integral Calculus -> Other']")): 1,
#          (('difficulty', '4'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Calculus -> Differential Calculus -> Limits']")): 1,
#          (('difficulty', '3'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility', 'Number Theory -> Elementary Number Theory -> Prime Numbers']")): 1,
#          (('difficulty', '5'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility', 'Number Theory -> Elementary Number Theory -> Modular Arithmetic']")): 1,
#          (('difficulty', '7'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility', 'Number Theory -> Elementary Number Theory -> Diophantine Equations']")): 1,
#          (('difficulty', '4'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations', 'Combinatorics -> Enumerative Combinatorics -> Other']")): 1,
#          (('difficulty', '4'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations', 'Algebra -> Intermediate Algebra -> Inequalities']")): 1,
#          (('difficulty', '7'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Diophantine Equations', 'Number Theory -> Elementary Number Theory -> Divisibility']")): 1,
#          (('difficulty', '2'),
#           ('domain',
#            "['Geometry -> Euclidean Geometry -> Triangles', 'Geometry -> Euclidean Geometry -> Circles']")): 1,
#          (('difficulty', '7'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility', 'Combinatorics -> Enumerative Combinatorics -> Other']")): 1,
#          (('difficulty', '7'),
#           ('domain',
#            "['Calculus -> Differential Calculus -> Applications of Derivatives', 'Algebra -> Intermediate Algebra -> Inequalities']")): 1,
#          (('difficulty', '2'),
#           ('domain',
#            "['Calculus -> Differential Calculus -> Applications of Derivatives', 'Algebra -> Intermediate Algebra -> Inequalities']")): 1,
#          (('difficulty', '3'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility', 'Combinatorics -> Enumerative Combinatorics -> Other']")): 1,
#          (('difficulty', '2'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Other', 'Algebra -> Intermediate Algebra -> Inequalities']")): 1,
#          (('difficulty', '3'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Other', 'Algebra -> Intermediate Algebra -> Other']")): 1,
#          (('difficulty', '7'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Functional Equations', 'Calculus -> Integral Calculus -> Other']")): 1,
#          (('difficulty', '1'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility', 'Algebra -> Intermediate Algebra -> Polynomials']")): 1,
#          (('difficulty', '2'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Prime Numbers', 'Algebra -> Intermediate Algebra -> Other']")): 1,
#          (('difficulty', '1'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Modular Arithmetic', 'Number Theory -> Elementary Number Theory -> Other']")): 1,
#          (('difficulty', '3'),
#           ('domain',
#            "['Geometry -> Analytic Geometry -> Conic Sections', 'Geometry -> Euclidean Geometry -> Coordinate Geometry']")): 1,
#          (('difficulty', '7'),
#           ('domain',
#            "['Number Theory -> Elementary Number Theory -> Divisibility', 'Algebra -> Intermediate Algebra -> Other']")): 1,
#          (('difficulty', '1'),
#           ('domain',
#            "['Algebra -> Intermediate Algebra -> Other', 'Geometry -> Euclidean Geometry -> Triangles']")): 1,
#          (('difficulty', '4'),
#           ('domain',
#            "['Combinatorics -> Enumerative Combinatorics -> Combinations', 'Number Theory -> Elementary Number Theory -> Other']")): 1,
#          (('difficulty', '6'),
#           ('domain', "['Calculus -> Differential Calculus -> Other']")): 1,
#          (('difficulty', '4'),
#           ('domain', "['Calculus -> Other -> Limits']")): 1,
#          ...})
