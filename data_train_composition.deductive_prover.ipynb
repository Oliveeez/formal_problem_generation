# %%
import os
import json
import pickle
import collections as C
import itertools as I
import random
import regex as re
import traceback
import asyncio

import dacite
from loguru import logger
from tqdm import tqdm

from common.constants import CORE_OPTIONS
from common.utils import remove_min_whitespace, remove_comments
from common.pantograph.dataclasses import Goal
from common.pantograph.server import PersistentServer

# %% [markdown]
# ## Correcting `header` field

# %%
with open('/home/ma-user/workspace/formal_problem_generation/formal_problem_generation/data/MiniF2F/Numina-Lean/train.deductive_prover.jsonl', 'r') as f:
    data = [json.loads(l) for l in f.readlines()]
len(data)
# Out:
# 34425

# %%
header = ("""
import Mathlib
import Aesop

""" + '\n'.join('set_option ' + t.replace('=', ' ') for t in CORE_OPTIONS)).strip()

OLD_CODE = r'''Assume the following header is executed:
```lean4
import Mathlib
import Aesop
```'''

NEW_CODE = f'''Assume the following header is executed:
```lean4
{header}
```'''
print(OLD_CODE)
print()
print(NEW_CODE)
# Out:
# Assume the following header is executed:
# ```lean4
# import Mathlib
# import Aesop
# ```
#
# Assume the following header is executed:
# ```lean4
# import Mathlib
# import Aesop
#
# set_option maxHeartbeats 0
# set_option maxRecDepth 100000
# set_option tactic.hygienic false
# set_option pp.fullNames true
# set_option pp.funBinderTypes true
# set_option pp.piBinderTypes true
# ```

# %%
for d in data:
    assert d['conversation'][0]['input'].startswith(OLD_CODE)
    d['conversation'][0]['input'] = NEW_CODE + d['conversation'][0]['input'][len(OLD_CODE):]

# %%
print(d['conversation'][0]['input'])
# Out:
# Assume the following header is executed:
# ```lean4
# import Mathlib
# import Aesop
#
# set_option maxHeartbeats 0
# set_option maxRecDepth 100000
# set_option tactic.hygienic false
# set_option pp.fullNames true
# set_option pp.funBinderTypes true
# set_option pp.piBinderTypes true
# ```
#
# Generate a deductive proof for the following Lean 4 proof state:
# ```lean4
# f : ℝ → ℝ
# a b c : ℝ
# hf : ∀ x ∈ Set.Icc (-1) 1, |f x| ≤ 1
# h₀ : ∀ (x : ℝ), f x = a * x ^ 2 + b * x + c
# ⊢ |a| + |b| + |c| ≤ 3
# ```

# %%
with open('/home/ma-user/workspace/formal_problem_generation/formal_problem_generation/data/MiniF2F/Numina-Lean/train.deductive_prover.header_corrected.jsonl', 'w') as f:
    for d in data:
        f.write(json.dumps(d) + '\n')

# %%
raise

# %% [markdown]
# ---

# %%
bracket_pairings = {
    '(' : ')',
    '[' : ']',
    '{' : '}',
    '⦃' : '⦄'
}

def parse_variables(s : str) -> tuple[str, str]:
    base = 0
    variables = []
    target = None
    while base < len(s):
        if s[base] in ['(', '[', '{', '⦃']:
            bracket_type = s[base]
            bracket_pairing = bracket_pairings[bracket_type]
        
            stack_cnt = 0
            start_end_positions = []

            for i, char in enumerate(s[base:]):
                if char == bracket_type:
                    if stack_cnt == 0:
                        start_position = i
                    stack_cnt += 1
                elif char == bracket_pairing:
                    if stack_cnt > 0:
                        stack_cnt -= 1
                        if stack_cnt == 0:
                            end_position = i
                            start_end_positions.append((start_position, end_position))
                            break
            
            start, end = start_end_positions[0]
            variables.append(s[base+start:base+end+1])
            base += i
        else:
            if s[base] == ':':
                target = s[base+1:]
                break
            base += 1
    
    return variables, target

# %%
with open('/home/ma-user/workspace/formal_problem_generation/formal_problem_generation/data/MiniF2F/Numina-Lean/deductive.20250818-162148.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
header = ("""
import Mathlib
import Aesop

""" + '\n'.join('set_option ' + t.replace('=', ' ') for t in CORE_OPTIONS)).strip()
print(header)
# Out:
# import Mathlib
# import Aesop
#
# set_option maxHeartbeats 0
# set_option maxRecDepth 100000
# set_option tactic.hygienic false
# set_option pp.fullNames true
# set_option pp.funBinderTypes true
# set_option pp.piBinderTypes true

# %%
for d in data:
    for u in d['parse_result']['units']:
        if 'deductive_steps' in u.keys():
            assert 'deductive_states' in u.keys()
            break

# %%
len(set([d['index'] for d in data])), len(data)
# Out:
# (38987, 38987)

# %%
tasks = [
    (d, u) for d in data for u in d['parse_result']['units'] if 'deductive_steps' in u.keys()
]
print(len(tasks))
# Out:
# 34448

# %%
available_servers = [
    PersistentServer(
        is_state_based=True,
        tag='test',
        _sync_init=False,
        imports=["Mathlib", "Aesop"],
        project_path='/home/ma-user/workspace/fps_pantograph/formal_problem_solving/data/MiniF2F',
        core_options=CORE_OPTIONS,
        timeout=300,
    ) for _ in range(32)
]

# %%
data_deductive_proof_generation = [None for _ in range(len(tasks))]

# %%
async def worker(d: dict, u: dict, idx: int, available_servers: list[PersistentServer]):
    server = available_servers.pop()
    server.tag = str(idx)
    try:
        # Reorganize Code
        p_raw = d['formal_code']
        import_list = d['parse_result']['import_list']
        open_scoped_list = d['parse_result']['open_scoped_list']
        open_list = d['parse_result']['open_list']
        option_list = d['parse_result']['option_list']

        tactic_header = ''
        load_header = ''
        if len(open_scoped_list):
            tactic_header += 'open scoped ' + ' '.join(t for t in open_scoped_list) + ' in\n'
            load_header += 'open scoped ' + ' '.join(t for t in open_scoped_list) + '\n'
        if len(open_list):
            tactic_header += 'open ' + ' '.join(t for t in open_list) + ' in\n'
            load_header += 'open ' + ' '.join(t for t in open_list) + '\n'
        if len(option_list):
            tactic_header += '\n'.join('set_option ' + t + ' in' for t in option_list) + '\n'
            load_header += '\n'.join('set_option ' + t for t in option_list) + '\n'

        p_injected: list[str] = p_raw.splitlines()
        for (i, l) in reversed(list(enumerate(p_injected))):
            if l.startswith('import '):
                i += 1
                break
        p_injected = '\n'.join(p_injected[:i]) + '\n\n' + '\n'.join('set_option ' + t.replace('=', ' ') for t in CORE_OPTIONS) + '\n\n' + '\n'.join(p_injected[i:])

        # Initialize
        invocations = u['invocations']
        assert len(invocations[0]['before']) == 1, 'Initial state contains multiple goals'

        code_segment = remove_comments(p_injected.encode()[u['i_begin']:u['i_end']].decode())
        start_pos = None
        for start_pos in re.finditer(r':=\s*by', code_segment):
            break
        assert start_pos is not None, '":= by" not found'
        statement_code, proof_code = code_segment[:start_pos.span(0)[0]], code_segment[start_pos.span(0)[1]:]

        # Preprocess steps
        for ivc in invocations:
            ivc['tactic'] = ivc['tactic'].replace('native_decide', 'decide')
        proof_code = proof_code.replace('native_decide', 'decide')

        # Parse Context from statement code
        context, target = parse_variables(statement_code)
        assert target is not None, f'Target parsing failed: {statement_code}'
        
        # Parse intros
        hypotheses = []
        intros = []
        
        for i_ctx, declaration in enumerate(context):
            if declaration[0] == '[':
                intros.append('_')
                hypotheses.append(declaration)
            else:
                assert '✝' not in declaration, f'declaration: {declaration}'
                try:
                    var_names, var_type = declaration[1:-1].split(':', 1)
                except ValueError:
                    var_names = declaration[1:-1]
                # var_names = [n if '✝' not in n else '_' for n in var_names.strip().split(' ')]
                intros.extend(var_names.strip().split(' '))
                hypotheses.append('(' + declaration[1:-1] + ')')    # Replace '{v : T}' into '(v : T)

        # Load statement
        # hypotheses = ('∀ ' + '\n'.join(
        #     '(' + ' '.join(var_names) + ' : ' + var_type + ')' if var_names != ['_'] else f'[{var_type}]' for (var_names, var_type) in telescope
        # ) + '\n, ') if len(context) > 0 else ''
        formal_statement = (('∀ ' + '\n'.join(hypotheses) + '\n, ') if len(hypotheses) > 0 else '') + target
        assert '⊢' not in formal_statement, '⊢ in formal_statement'

        init_state = await server.load_statement_async(formal_statement, intros=intros, header=load_header)
        assert [g.serialize() for g in init_state.goals] == u['deductive_states'][0], "[g.serialize() for g in init_state.goals] != u['deductive_states'][0]"
        
        proof = ''
        for tactic_header, step in u['deductive_steps']:
            if len(tactic_header) > 0:
                proof += tactic_header
            proof += remove_min_whitespace(step) + '\n\n'
        proof = proof.strip()
        
        final_state = await server.goal_tactic_async(init_state, 0, '{\n' + proof + '\n}')
        assert final_state.is_solved, 'final_state.is_solved Failed'

        data_deductive_proof_generation[idx] = {
            "conversation":[
                {
                    "input": f"""
Assume the following header:
```lean4
{header}
```

Generate a proof for the Lean 4 proof state:

```lean4
{str(init_state)}
```
""".strip(),
                    "output": proof
                }
            ]
        }
    except Exception as e:
        logger.warning(f'worker({idx}): Failed due to {repr(e)}:\n{traceback.format_exc()}')
    finally:
        server.tag = ''
        available_servers.insert(0, server)

# %%
async def _async_main():
    pending_tasks: set[asyncio.Task] = set()
    loop = list(enumerate(tasks))
    for i, (d, u) in tqdm(loop):
        if len(pending_tasks) >= 16:
            done_tasks, pending_tasks = await asyncio.wait(pending_tasks, return_when=asyncio.FIRST_COMPLETED)
            for task in done_tasks:
                if task.exception() is not None:
                    logger.error(f"Exception occurred: {task.exception()} {task.get_stack()}")
                    for pending_task in pending_tasks:
                        pending_task.cancel()
                    return
        pending_tasks.add(
            asyncio.create_task(
                worker(d, u, i, available_servers)
            )
        )
    if len(pending_tasks) > 0:
        await asyncio.wait(pending_tasks)
    await logger.complete()

# %%
asyncio.run(_async_main())
# Out:
#   0%|          | 0/34448 [00:00<?, ?it/s]2025-08-18 19:32:43.949 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(0): Restarting...
# 2025-08-18 19:32:44.796 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(1): Restarting...
# 2025-08-18 19:32:45.541 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(2): Restarting...
# 2025-08-18 19:32:46.400 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(3): Restarting...
# 2025-08-18 19:32:47.376 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(4): Restarting...
# 2025-08-18 19:32:48.427 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(5): Restarting...
# 2025-08-18 19:32:49.478 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(6): Restarting...
# 2025-08-18 19:32:50.529 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(7): Restarting...
# 2025-08-18 19:32:51.580 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(8): Restarting...
# 2025-08-18 19:32:52.639 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(9): Restarting...
# 2025-08-18 19:32:53.526 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(10): Restarting...
# 2025-08-18 19:32:54.394 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(11): Restarting...
# 2025-08-18 19:32:55.445 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(12): Restarting...
# 2025-08-18 19:32:56.522 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(13): Restarting...
# 2025-08-18 19:32:57.589 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(14): Restarting...
# 2025-08-18 19:32:58.458 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(15): Restarting...
#   0%|          | 17/34448 [00:19<10:48:26,  1.13s/it]2025-08-18 19:33:03.159 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(16): Restarting...
# 2025-08-18 19:33:04.178 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(17): Restarting...
#   0%|          | 19/34448 [00:21<10:44:31,  1.12s/it]2025-08-18 19:33:05.326 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(18): Restarting...
# 2025-08-18 19:33:06.389 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(19): Restarting...
#   0%|          | 21/34448 [00:23<10:50:24,  1.13s/it]2025-08-18 19:33:07.694 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(20): Restarting...
# 2025-08-18 19:33:08.698 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(21): Restarting...
# 2025-08-18 19:33:09.672 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(22): Restarting...
# 2025-08-18 19:33:10.439 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(23): Restarting...
#   0%|          | 25/34448 [00:27<10:30:40,  1.10s/it]2025-08-18 19:33:11.808 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(24): Restarting...
#   0%|          | 26/34448 [00:29<11:11:22,  1.17s/it]2025-08-18 19:33:13.586 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(25): Restarting...
#   0%|          | 27/34448 [00:30<11:15:29,  1.18s/it]2025-08-18 19:33:14.811 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(26): Restarting...
# 2025-08-18 19:33:15.576 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(27): Restarting...
# 2025-08-18 19:33:16.338 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(28): Restarting...
#   0%|          | 30/34448 [00:33<10:21:23,  1.08s/it]2025-08-18 19:33:17.555 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(29): Restarting...
# 2025-08-18 19:33:18.315 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(30): Restarting...
# 2025-08-18 19:33:19.080 | DEBUG    | common.pantograph.server:check_restart_async:566 - PersistentServer(31): Restarting...
#   1%|          | 331/34448 [01:50<3:10:15,  2.99it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 asyncio.run(_async_main())
#
# File ~/anaconda3/envs/default/lib/python3.11/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~/anaconda3/envs/default/lib/python3.11/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File ~/anaconda3/envs/default/lib/python3.11/site-packages/nest_asyncio.py:133, in _patch_loop.<locals>._run_once(self)
#     130 curr_task = curr_tasks.pop(self, None)
#     132 try:
# --> 133     handle._run()
#     134 finally:
#     135     # restore the current task
#     136     if curr_task is not None:
#
# File ~/anaconda3/envs/default/lib/python3.11/asyncio/events.py:84, in Handle._run(self)
#      82 def _run(self):
#      83     try:
# ---> 84         self._context.run(self._callback, *self._args)
#      85     except (SystemExit, KeyboardInterrupt):
#      86         raise
#
# File ~/anaconda3/envs/default/lib/python3.11/asyncio/tasks.py:360, in Task.__wakeup(self, future)
#     352     self.__step(exc)
#     353 else:
#     354     # Don't pass the value of `future.result()` explicitly,
#     355     # as `Future.__iter__` and `Future.__await__` don't need it.
#    (...)    358     # instead of `__next__()`, which is slower for futures
#     359     # that return non-generator iterators from their `__iter__`.
# --> 360     self.__step()
#     361 self = None
#
# File ~/anaconda3/envs/default/lib/python3.11/asyncio/tasks.py:277, in Task.__step(***failed resolving arguments***)
#     273 try:
#     274     if exc is None:
#     275         # We use the `send` method directly, because coroutines
#     276         # don't have `__iter__` and `__next__` methods.
# --> 277         result = coro.send(None)
#     278     else:
#     279         result = coro.throw(exc)
#
# Cell In[10], line 76, in worker(d, u, idx, available_servers)
#      73 formal_statement = (('∀ ' + '\n'.join(hypotheses) + '\n, ') if len(hypotheses) > 0 else '') + target
#      74 assert '⊢' not in formal_statement, '⊢ in formal_statement'
# ---> 76 init_state = await server.load_statement_async(formal_statement, intros=intros, header=load_header)
#      77 assert [g.serialize() for g in init_state.goals] == u['deductive_states'][0], "[g.serialize() for g in init_state.goals] != u['deductive_states'][0]"
#      79 proof = ''
#
# File /cache/workspace/formal_problem_generation/formal_problem_generation/common/pantograph/server.py:540, in record_server_error.<locals>.wrapper(self, *args, **kwargs)
#     538 async def wrapper(self, *args, **kwargs):
#     539     try:
# --> 540         result = await func(self, *args, **kwargs)
#     541         return result
#     542     except (ServerError, TimeoutError, pexpect.exceptions.TIMEOUT) as e:
#
# File /cache/workspace/formal_problem_generation/formal_problem_generation/common/pantograph/server.py:592, in PersistentServer.load_statement_async(self, statement, intros, header)
#     590 init_state = await self.server.goal_tactic_async(prev_init_state, 1, 'trivial')
#     591 if len(intros) > 0:
# --> 592     init_state = await self.server.goal_tactic_async(init_state, 0,
#     593         'intros ' + ' '.join(intros)
#     594     )
#     595 assert len(init_state.goals) == 1, f'PersistentServer({self.tag}): {[init_state]}'
#     597 return init_state
#
# File /cache/workspace/formal_problem_generation/formal_problem_generation/common/pantograph/server.py:318, in Server.goal_tactic_async(self, state, goal_id, tactic)
#     316 else:
#     317     raise TacticFailure(f"Invalid tactic type: {tactic}")
# --> 318 result = await self.run_async('goal.tactic', args)
#     319 if "error" in result:
#     320     raise ServerError(result, str(state), tactic)
#
# File /cache/workspace/formal_problem_generation/formal_problem_generation/common/pantograph/server.py:228, in Server.run_async(self, cmd, payload)
#     226 # self.proc.sendline(f"{cmd} {s}")
#     227 for _, chunk in chunk_list(f"{cmd} {s}\n", 1024):
# --> 228     self.proc.sendline(chunk)
#     230 try:
#     231     line = await self.proc.readline_async()
#
# File ~/anaconda3/envs/default/lib/python3.11/site-packages/pexpect/pty_spawn.py:578, in spawn.sendline(self, s)
#     572 '''Wraps send(), sending string ``s`` to child process, with
#     573 ``os.linesep`` automatically appended. Returns number of bytes
#     574 written.  Only a limited number of bytes may be sent for each
#     575 line in the default terminal mode, see docstring of :meth:`send`.
#     576 '''
#     577 s = self._coerce_send_string(s)
# --> 578 return self.send(s + self.linesep)
#
# File ~/anaconda3/envs/default/lib/python3.11/site-packages/pexpect/pty_spawn.py:563, in spawn.send(self, s)
#     528 '''Sends string ``s`` to the child process, returning the number of
#     529 bytes written. If a logfile is specified, a copy is written to that
#     530 log.
#    (...)    559     >>> bash.sendline('x' * 5000)
#     560 '''
#     562 if self.delaybeforesend is not None:
# --> 563     time.sleep(self.delaybeforesend)
#     565 s = self._coerce_send_string(s)
#     566 self._log(s, 'send')
#
# KeyboardInterrupt:
